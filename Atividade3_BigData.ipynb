# %% [markdown]
# # Atividade 3

# %% [markdown]
# **Membros:**
#
# *   Giulia Monteiro Garrido (RA: 24010281)
# *   Thomaz Dacorso (RA: 24012310)
# *   Victor França (RA: 24010801)
# *   Vitor Furuta (RA: 24008775)

# %% [markdown]
# ### 1. Simulação de Streaming dos Dados Novos

# %%
from watchdog.events import FileSystemEventHandler

# %%
class check_arquivo(FileSystemEventHandler):

    def on_modified(self, event):
        print(f"O arquivo {event.src_path} foi modificado")

    def on_created(self, event):
        print(f"Novo arquivo detectado: {event.src_path}")

# %%
empty_file_path =

# %%
check_arquivo.on_modified()
